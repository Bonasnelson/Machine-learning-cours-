# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
cardata = pd.read_csv('../dataset/cars.csv')
cardata.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# ...

# %%
print(cardata.describe())
print(cardata.value_counts())
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count    38531.000000   38531.000000     38521.000000  38531.000000
# mean    248864.638447    2002.943734         2.055161   6639.971021
# std     136072.376530       8.065731         0.671178   6428.152018
# min          0.000000    1942.000000         0.200000      1.000000
# 25%     158000.000000    1998.000000         1.600000   2100.000000
# 50%     250000.000000    2003.000000         2.000000   4800.000000
# 75%     325000.000000    2009.000000         2.300000   8990.000000
# max    1000000.000000    2019.000000         8.000000  50000.000000
#
#        number_of_photos    up_counter  duration_listed
# count      38531.000000  38531.000000     38531.000000
# mean           9.649062     16.306091        80.577249
# std            6.093217     43.286933       112.826569
# min            1.000000      1.000000         0.000000
# 25%            5.000000      2.000000        23.000000
# ...

# %%
print(cardata.isnull().sum())
# Out:
# manufacturer_name     0
# model_name            0
# transmission          0
# color                 0
# odometer_value        0
# year_produced         0
# engine_fuel           0
# engine_has_gas        0
# engine_type           0
# engine_capacity      10
# body_type             0
# has_warranty          0
# state                 0
# drivetrain            0
# price_usd             0
# is_exchangeable       0
# location_region       0
# number_of_photos      0
# up_counter            0
# feature_0             0
# feature_1             0
# feature_2             0
# feature_3             0
# feature_4             0
# feature_5             0
# feature_6             0
# feature_7             0
# feature_8             0
# feature_9             0
# duration_listed       0
# dtype: int64

# %%
cardata = pd.get_dummies(cardata)

# %%
#Les variables qualitatives
categorical = [var for var in cardata.columns if cardata[var].dtype == 'O']
    #Les variables continues
numerical = [var for var in cardata.columns if cardata[var].dtype != 'O']

# %%
data = pd.get_dummies(data)
for cardata in [cardata]:
        for col in numerical:
            col_median = cardata[col].median()
            cardata[col].fillna(col_median, inplace=True)
        for col in categorical:
            cardata[col].fillna(cardata[col].mode()[0], inplace=True)

# %%
cardata2 = cardata.copy()

# %%
cardata2.head()
# Out:
#    odometer_value  year_produced  engine_has_gas  engine_capacity  \
# 0          190000           2010           False              2.5
# 1          290000           2002           False              3.0
# 2          402000           2001           False              2.5
# 3           10000           1999           False              3.0
# 4          280000           2001           False              2.5
#
#    has_warranty  price_usd  is_exchangeable  number_of_photos  up_counter  \
# 0         False   10900.00            False                 9          13
# 1         False    5000.00             True                12          54
# 2         False    2800.00             True                 4          72
# 3         False    9999.00             True                 9          42
# 4         False    2134.11             True                14           7
#
#    feature_0  ...  state_owned  drivetrain_all  drivetrain_front  \
# ...

# %%
scaler = StandardScaler()
cardata2 = scaler.fit_transform(cardata2)

# %%
cardata2
# Out:
# array([[-0.43260362,  0.87485665, -0.19032934, ..., -0.26256368,
#          0.76825695, -0.27330183],
#        [ 0.30230894, -0.11700687, -0.19032934, ..., -0.26256368,
#          0.76825695, -0.27330183],
#        [ 1.125411  , -0.24098981, -0.19032934, ..., -0.26256368,
#          0.76825695, -0.27330183],
#        ...,
#        [ 3.88836618, -0.36497275, -0.19032934, ..., -0.26256368,
#          0.76825695, -0.27330183],
#        [-1.68195496, -0.24098981, -0.19032934, ..., -0.26256368,
#         -1.30164785, -0.27330183],
#        [ 0.35911033, -0.36497275, -0.19032934, ..., -0.26256368,
#          0.76825695, -0.27330183]])

# %%
print(cardata.describe())
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count    38531.000000   38531.000000     38531.000000  38531.000000
# mean    248864.638447    2002.943734         2.055147   6639.971021
# std     136072.376530       8.065731         0.671091   6428.152018
# min          0.000000    1942.000000         0.200000      1.000000
# 25%     158000.000000    1998.000000         1.600000   2100.000000
# 50%     250000.000000    2003.000000         2.000000   4800.000000
# 75%     325000.000000    2009.000000         2.300000   8990.000000
# max    1000000.000000    2019.000000         8.000000  50000.000000
#
#        number_of_photos    up_counter  duration_listed  \
# count      38531.000000  38531.000000     38531.000000
# mean           9.649062     16.306091        80.577249
# std            6.093217     43.286933       112.826569
# min            1.000000      1.000000         0.000000
# 25%            5.000000      2.000000        23.000000
# ...

# %%
pca = PCA()
pca2 = PCA()
cardata2 = pca2.fit_transform(cardata2)
cardata = pca.fit_transform(cardata)

# %%
cardata2
# Out:
# array([[ 4.40015892e+00,  1.33996463e+00, -8.49657889e-01, ...,
#         -2.12112521e-15, -3.24342785e-15, -8.07738187e-16],
#        [ 2.57199190e+00,  1.22698381e+00, -1.48166706e+00, ...,
#         -2.26078875e-15, -3.73567513e-16, -1.56324278e-15],
#        [ 2.12854066e+00,  1.56082484e+00, -1.31150884e+00, ...,
#          7.36699388e-17,  6.87577557e-16,  6.33780092e-16],
#        ...,
#        [ 1.53042986e+00,  7.90638903e-01, -2.96480266e+00, ...,
#          1.35197265e-16,  1.20568312e-17,  9.40358467e-17],
#        [-8.42183043e-01,  1.21607643e+00, -1.25936599e+00, ...,
#          2.68330580e-16, -1.41994093e-17, -1.34079801e-17],
#        [-6.08734001e-01,  8.97872590e-01, -1.22758362e+00, ...,
#          4.97491085e-16, -1.54032419e-16,  1.08544840e-17]])

# %%
print(pca.explained_variance_)
print(pca2.explained_variance_)
# Out:
# [1.85230361e+10 3.39767966e+07 1.36904620e+04 ... 2.00996405e-33
#  1.90126508e-33 5.09461435e-34]
# [8.64685332e+00 5.20771148e+00 4.14108065e+00 ... 1.57926651e-31
#  1.44601987e-31 1.25951444e-31]

# %%
print(np.sum(pca.explained_variance_ratio_))
print(np.sum(pca2.explained_variance_ratio_))
# Out:
# 1.0000000000000002
# 1.0

# %%
print(pca.explained_variance_ratio_)
print(pca2.explained_variance_ratio_)
# Out:
# [9.98168271e-01 1.83093961e-03 7.37750806e-07 ... 1.08312824e-43
#  1.02455260e-43 2.74538277e-44]
# [6.97308782e-03 4.19965833e-03 3.33949450e-03 ... 1.27356897e-34
#  1.16611479e-34 1.01571109e-34]
